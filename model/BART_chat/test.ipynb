# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install transformers
# !pip install parlai
# !parlai display_data -t msc:PersonaSummary --include-last-session True
# !pip install names
# !pip install gingerit

# %%
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM

# %%
def getSpeakerNames():
  speaker_1 = names.get_first_name()
  speaker_2 = names.get_first_name()
  while(speaker_1 == speaker_2):
    speaker_2 = names.get_first_name()
  return speaker_1, speaker_2

# %%
from gingerit.gingerit import GingerIt

grammer_parser = GingerIt()

# %%
import re
import json
import names
# Read the JSON file
folder_path = '/usr/local/lib/python3.10/dist-packages/data/msc/msc/msc_personasummary'

def createDataset(mode):
    s1_data_path = f"{folder_path}/session_1/{mode}.txt"
    s2_data_path = f"{folder_path}/session_2/{mode}.txt"
    s3_data_path = f"{folder_path}/session_3/{mode}.txt"
    s4_data_path = f"{folder_path}/session_4/{mode}.txt"

    if mode == 'train':
        data_paths = [s1_data_path, s2_data_path, s3_data_path]
    else:
        data_paths = [s1_data_path, s2_data_path, s3_data_path, s4_data_path]

    mode_X = []
    mode_y = []
    # 데이터 파일 열기

    for data_path in data_paths:
        with open(data_path, 'r', encoding='utf-8') as f:
            for line in f:
                # 한 줄씩 읽기
                data = json.loads(line)
                train_data = ""
                agg_persona_list = []
                name1, name2 = getSpeakerNames()
                for i, utterance in enumerate(data['dialog']):
                    if utterance['id'] != 'bot_0' and utterance['id'] != 'bot_1': assert(0)
                    speaker_name = name1 if utterance['id'] == 'bot_0' else name2
                    text = utterance['text']
                    summary = utterance['agg_persona_list']
                    for i in range(len(summary)):
                        summary[i] = summary[i].replace('I', speaker_name)
                        summary[i] = summary[i].replace("'ve", "'s")

                    # 이어붙이기
                    train_data += f"{speaker_name}: {text}\r\n"
                    agg_persona_list.extend(summary)
                train_data = train_data.rstrip('\r\n')
                agg_persona_list = list(dict.fromkeys(agg_persona_list))
                joined_summaries = " ".join(agg_persona_list)
                # print(train_data)
                # print(joined_summaries)
                mode_X.append(train_data)
                mode_y.append(joined_summaries)
    return mode_X, mode_y

# %%
train_X, train_y = createDataset('train')
valid_X, valid_y = createDataset('valid')
test_X, test_y = createDataset('test')

# %%
len(train_X), len(valid_X), len(test_X)
# Out:
# (10285, 2000, 2004)

# %%
model_name = "BART_chat/checkpoint-1200"
model_dir = f"drive/MyDrive/Colab Notebooks/Metabuddy/Models/{model_name}"
max_input_length = 512

tokenizer = AutoTokenizer.from_pretrained(model_dir)
model = AutoModelForSeq2SeqLM.from_pretrained(model_dir)

# %%
import random

def showTestResults(mode):
    if mode == 'train':
        dataset = train_X
        label = train_y
        _len = len(train_X)
    elif mode == 'valid':
        dataset = valid_X
        label = valid_y
        _len = len(valid_X)
    else:
        dataset = test_X
        label = test_y
        _len = len(test_X)

    for _ in range(5):
        ri = random.randint(0, _len)

        input_text = dataset[ri]
        inputs = tokenizer([input_text], max_length=max_input_length, truncation=True, return_tensors="pt")
        outputs = model.generate(**inputs, max_length=100, num_return_sequences=1, early_stopping=True)

        print("<Index : ",ri, '>')
        print("Input : ", dataset[ri])
        print("Output: ")
        for output in outputs:
            summarized_text = tokenizer.decode(output, skip_special_tokens=True)
            summarized_text = grammer_parser.parse(summarized_text)['result']
            print(summarized_text)

        _label = grammer_parser.parse(label[ri])['result']
        print("Label : ", _label)
        print("ㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡ
# ㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡ
# <Index :  3721 >
# Input :  Joseph: Hi am sam and I have long hair for guy
# Yvette: Well, I have 4 girls!
# Joseph: I've no girls, and I want to live in a fantasy world
# Yvette: What kind? I just got done racing cars, and playing board games
# Joseph:
# Yvette: Well, you could try fishing!
# Joseph: I want to be in a place where its about me for once.
# Yvette: How come it is not about you?
# Joseph: Because my parents are selfish people. Even though I do well in school its about them
# Yvette: Well, that'sn't fun!
# Joseph: Even though I draw in class instead of taking notes I still get straight as
# Yvette: Well, as are a good thing to have!
# Joseph: They want me live vicariously through me... I hate it when they do that.
# Yvette: Do they get mad at you?
# Joseph: They do, and it is my responsibility to make them happy when they take things.
# Yvette: I think it is there thing, not yours
# Joseph: I have had money taken from me and it made me mad, because I owed them.
# Yvette: I don't think you owed them!
# Joseph: Well that is what they said because they raised me why have me then?
# Yvette: That is a horrible thing to say!
# Joseph: Your telling me. I'm sorry I will go, thanks for talking with me.
# Yvette: You don't have to go if you don't want to!
# Joseph: Well I think its more like just don't know what to say.. About it
# Yvette: Well, could you just tell them how you feel?
# Joseph: I've and they don't listen. They prefer to just pretend like its not happening
# Yvette: Well, that's not good, and I don't think it is right
# Joseph: I do not think so either. I'm sorry for venting like this it makes me mad.
# Yvette: No, it is totally fine, I'm here to listen
# Joseph: Thank you so much for listening.
# Yvette: Oh, you are welcome, anytime!
# Output:
# My name is Sam. Joseph has long hair. Yvette has 4 daughters. Joseph doesn't have any daughters. My hobbies are racing cars and playing board games. Joseph like fishing. My parents are selfish. Joseph do well in school. Joseph draws in class instead of taking notes. Joseph hates it when my parents take things from me. Joseph had money taken from me because Joseph owed them.
# Label :  My name is Sam. Joseph has long hair for a guy. Yvette has four daughters. Joseph wants to live in a fantasy world. Joseph has no daughters. My parents are selfish. Joseph do well in school. Joseph gets straight A's. Joseph hates when my parents want to live vicariously through me. Yvette likes to go fishing. My parents don't listen to me.
# ㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡ
# <Index :  1833 >
# Input :  Bruce: Hello! Tell me about yourself, I need something to write about
# Geraldine: Hey there! Well, I just started classes in college and work part time at the campus library
# Bruce: That sounds fun. What classes are you taking?
# Geraldine: I am taking 2 science classes. I am wondering if I should just move on campus
# Bruce: That wouldn't be horrible. I used to work in a book store on campus
# Geraldine: Yes, well right now I have catch the bus. Maybe I'll do dorms next year
# Bruce: I liked my dorm in college. That's where I started my tea addiction.
# Geraldine: We have been studying tea in one of my 3 science classes!
# Bruce: Haha that's hilarious! Learn anything I should know about?
# Geraldine: Yeah, its not looking good for you my friend
# Bruce: Oh no. What is so bad about it?
# Geraldine: It stains your teeth, and is generally unhealthy for you
# Bruce: Well I can deal with stained teeth. How is it unhealthy?
# Geraldine: We are still studying it further, but it turns out as you said, it is addicting
# Bruce: Yeah. That is very true. It also probably doesn't help that they have it in art museums
# Geraldine: So what else do you enjoy?
# Output:
# Geraldine works part time at the campus library. Geraldine, just started college classes and am taking 2 science classes. Bruce used to work in a bookstore on campus. Bruce started my tea addiction in college. Bruce lived in a dorm. We have been studying tea in one of my 3 science classes.
# Label :  Geraldine has a part time job at the library. Geraldine'm attending college. Geraldine don't currently live on campus. Geraldine'm taking 2 science classes. Bruce used to work in a book store. Bruce enjoys tea. Bruce lived in the dorms in college. Geraldine'm studying tea in one of my classes.
# ㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡ

# %%
mode = 'valid'
showTestResults(mode)
